# %%
###############
## SET UP
###############

# API key is intered by the input command. Do NOT save the API-Key in the code. Don't edit the code below
if 'apikey' not in locals():
    apikey = input(prompt='API-Key? ( https://cloud.ibm.com/catalog/services/natural-language-understanding )')  

### SCRIPT INPUT HYPER-PARAMETERS 
# Change as desired when running the script. 
PATH = {}
PATH['data']    = '../data/Documents/'
PATH['results'] = './Watson-nlu-results/'

NLU = {}
NLU['url']            = 'https://gateway.watsonplatform.net/natural-language-understanding/api'
NLU['version']        = '2019-07-12'
NLU['Max concepts']   = 10
NLU['Max categories'] = 10

##################
### IMPORT MODULES
##################
### Processing
import numpy as np
import scipy as sp
import pandas as pd

### System
import sys
from os import listdir

### I/O
import json
import pickle

### Presentation
from matplotlib import pyplot as plt

### NLU
from ibm_watson import NaturalLanguageUnderstandingV1 as NaLaUn
from ibm_watson.natural_language_understanding_v1 import Features, CategoriesOptions,ConceptsOptions
nlu = NaLaUn(version=nlu_version , iam_apikey = apikey, url = nlu_url)  #Local Natural Language Understanding object

################
## PREPARE DATA 
################
filenames = listdir(PATH['data']) 
dictation_dic = {}            #dictionary for dictation files
for name in filenames:
    dictation_dic[name.replace('.txt','')] = open(PATH['data']+name).read()

def select_dictation(key):
    if type(key) is int:
        aa = list(dictation_dic.values())[key]
    else:
        aa = dictation_dic[key]
    return aa
dn = select_dictation           # dn <- Short name for select_dictation

###############################
## PERFORM WATSON NLU ANALYSIS
###############################
dictation_analysis = {}
dian = dictation_analysis

features = Features(
    categories=CategoriesOptions(limit=NLU['Max categories']),
    concepts  =ConceptsOptions(limit=NLU['Max concepts'] )
)

for item in list(dictation_dic.items()):
    lbl  = item[0]
    text = item[1]
    dian[lbl] = nlu.analyze(text = text, features=features)
    f = open(PATH['results']+str(lbl)+'_nlu.pkl','wb')
    pickle.dump(dian[lbl],f)
    f.close()

f = open(PATH['results']+'all_dictations_nlu.pkl','wb')
pickle.dump(dian,f)
f.close()

# %%
list(dian.items())[0][1].result['concepts']
# Out:
# [{'text': 'Diabetes mellitus',
#   'relevance': 0.957687,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Diabetes_mellitus'},
#  {'text': 'Hypertension',
#   'relevance': 0.936508,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Hypertension'},
#  {'text': 'John Cavil',
#   'relevance': 0.929445,
#   'dbpedia_resource': 'http://dbpedia.org/resource/John_Cavil'},
#  {'text': 'Myocardial infarction',
#   'relevance': 0.829196,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Myocardial_infarction'},
#  {'text': 'Battlestar Galactica: The Plan',
#   'relevance': 0.783326,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Battlestar_Galactica:_The_Plan'},
#  {'text': 'Samuel Anders',
#   'relevance': 0.749737,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Samuel_Anders'},
#  {'text': "Parkinson's disease",
#   'relevance': 0.734969,
#   'dbpedia_resource': "http://dbpedia.org/resource/Parkinson's_disease"},
#  {'text': 'Medicine',
#   'relevance': 0.704325,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Medicine'},
#  {'text': 'Blood pressure',
#   'relevance': 0.6722,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Blood_pressure'},
#  {'text': 'Obesity',
#   'relevance': 0.66707,
#   'dbpedia_resource': 'http://dbpedia.org/resource/Obesity'}]
